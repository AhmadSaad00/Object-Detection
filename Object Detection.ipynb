# %%
import cv2
from ultralytics import YOLO

# %%
def getColours(cls_num):
    base_colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255)]
    color_index = cls_num % len(base_colors)
    increments = [(1, -2, 1), (-2, 1, -1), (1, -1, 2)]
    color = [base_colors[color_index][i] + increments[color_index][i] * 
    (cls_num // len(base_colors)) % 256 for i in range(3)]
    return tuple(color)

# %%
yolo = YOLO('yolov8s.pt')

# %%
videoCap = cv2.VideoCapture('golf.mp4')

# %%
while True:
    ret, frame = videoCap.read()
    if not ret:
        break  # Exit loop if video ends

    # Process the frame with YOLO tracking
    results = yolo.track(frame, stream=True)

    # Flag to check if any object is detected
    object_detected = False

    for result in results:  # Iterate over YOLO results
        object_detected = True  # Set flag to true if results are found
        classes_names = result.names  # Access the detected class names

        # Iterate over each bounding box
        for box in result.boxes:
            if box.conf[0] > 0.4:  # Check if confidence > 40%
                # Get coordinates and class info
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cls = int(box.cls[0])
                class_name = classes_names[cls]

                # Get respective color
                colour = getColours(cls)

                # Draw the rectangle and label on the frame
                cv2.rectangle(frame, (x1, y1), (x2, y2), colour, 2)
                cv2.putText(frame, f'{class_name} {box.conf[0]:.2f}',
                            (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, colour, 2)

    # Display the frame
    cv2.namedWindow('frame', cv2.WINDOW_NORMAL)
    cv2.imshow('frame', frame)

    # Break loop on key press 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Release resources
videoCap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 1 sports ball, 393.5ms
# Speed: 26.1ms preprocess, 393.5ms inference, 41.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 231.2ms
# Speed: 0.0ms preprocess, 231.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 210.2ms
# Speed: 1.9ms preprocess, 210.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 240.3ms
# Speed: 3.4ms preprocess, 240.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 214.9ms
# Speed: 8.1ms preprocess, 214.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 239.2ms
# Speed: 8.4ms preprocess, 239.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 1 baseball bat, 246.4ms
# Speed: 7.8ms preprocess, 246.4ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 276.2ms
# Speed: 0.0ms preprocess, 276.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 245.6ms
# Speed: 8.1ms preprocess, 245.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 fire hydrant, 288.8ms
# Speed: 3.4ms preprocess, 288.8ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 fire hydrant, 247.7ms
# Speed: 8.3ms preprocess, 247.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 254.6ms
# Speed: 0.0ms preprocess, 254.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 307.7ms
# Speed: 4.2ms preprocess, 307.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 304.3ms
# Speed: 0.0ms preprocess, 304.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 321.6ms
# Speed: 0.0ms preprocess, 321.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 323.0ms
# Speed: 0.0ms preprocess, 323.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 205.5ms
# Speed: 0.0ms preprocess, 205.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 248.6ms
# Speed: 3.1ms preprocess, 248.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 239.1ms
# Speed: 0.0ms preprocess, 239.1ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 247.5ms
# Speed: 0.0ms preprocess, 247.5ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 304.2ms
# Speed: 0.0ms preprocess, 304.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 322.3ms
# Speed: 9.7ms preprocess, 322.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 306.1ms
# Speed: 8.1ms preprocess, 306.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 303.7ms
# Speed: 1.7ms preprocess, 303.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 320.6ms
# Speed: 0.0ms preprocess, 320.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 289.1ms
# Speed: 0.0ms preprocess, 289.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 271.1ms
# Speed: 8.6ms preprocess, 271.1ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 263.8ms
# Speed: 5.0ms preprocess, 263.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 sports ball, 311.0ms
# Speed: 0.0ms preprocess, 311.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 baseball bat, 300.9ms
# Speed: 5.5ms preprocess, 300.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 baseball bat, 309.9ms
# Speed: 10.1ms preprocess, 309.9ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 318.5ms
# Speed: 0.0ms preprocess, 318.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
